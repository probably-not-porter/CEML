# %% [markdown]
# # APRIL 8 TESTS
# # RESNET34
# # ONE ALGORITHM AND ONE ORIGINAL CHANNEL

# %%
from pipeline_for_testing import full_pipe

# %%
full_pipe("/../training/chest-xray")
# Out:
# CONTROL
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.575204</td>
#       <td>0.280248</td>
#       <td>0.881902</td>
#       <td>0.118098</td>
#       <td>12:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.475474</td>
#       <td>0.420866</td>
#       <td>0.835890</td>
#       <td>0.164110</td>
#       <td>12:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.526026</td>
#       <td>0.208095</td>
#       <td>0.916794</td>
#       <td>0.083206</td>
#       <td>12:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.374955</td>
#       <td>0.214779</td>
#       <td>0.914877</td>
#       <td>0.085123</td>
#       <td>12:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
full_pipe("/../training/dogs-cats")
# Out:
# CONTROL
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.605460</td>
#       <td>0.230635</td>
#       <td>0.913000</td>
#       <td>0.087000</td>
#       <td>16:57</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.571881</td>
#       <td>0.132063</td>
#       <td>0.953750</td>
#       <td>0.046250</td>
#       <td>17:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.464929</td>
#       <td>0.230517</td>
#       <td>0.912750</td>
#       <td>0.087250</td>
#       <td>17:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.317578</td>
#       <td>0.136299</td>
#       <td>0.964250</td>
#       <td>0.035750</td>
#       <td>17:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
full_pipe("/../training/intel-images")
# Out:
# CONTROL
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.378381</td>
#       <td>0.586844</td>
#       <td>0.797207</td>
#       <td>0.202793</td>
#       <td>30:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.061823</td>
#       <td>0.580105</td>
#       <td>0.797064</td>
#       <td>0.202936</td>
#       <td>30:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.963991</td>
#       <td>0.452127</td>
#       <td>0.827847</td>
#       <td>0.172153</td>
#       <td>30:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.779510</td>
#       <td>0.345476</td>
#       <td>0.882998</td>
#       <td>0.117002</td>
#       <td>30:34</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

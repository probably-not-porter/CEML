# %% [markdown]
# # APRIL 18 TESTS
# # RESNET18
# # ONE ALGORITHM + SOBEL_Y + ORIGINAL
#
# it says "x and original" but its actually "X and original and sobel_y" layers in this one
#
# SET TO USE RESNET18 IN THE SOURCE CODE FOR TESTING

# %%
from pipeline_for_testing import full_pipe

# %%
full_pipe("/../training/chest-xray")
# Out:
# CONTROL
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.510048</td>
#       <td>0.286773</td>
#       <td>0.902224</td>
#       <td>0.097776</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.443006</td>
#       <td>0.343995</td>
#       <td>0.876917</td>
#       <td>0.123083</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.475847</td>
#       <td>0.277533</td>
#       <td>0.879218</td>
#       <td>0.120782</td>
#       <td>07:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.426585</td>
#       <td>0.156907</td>
#       <td>0.937117</td>
#       <td>0.062883</td>
#       <td>07:52</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
full_pipe("/../training/chest-xray")
# Out:
# CONTROL
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.585078</td>
#       <td>0.253851</td>
#       <td>0.901457</td>
#       <td>0.098543</td>
#       <td>08:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.525188</td>
#       <td>0.245664</td>
#       <td>0.896089</td>
#       <td>0.103911</td>
#       <td>08:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.503279</td>
#       <td>0.234906</td>
#       <td>0.901074</td>
#       <td>0.098926</td>
#       <td>08:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.305203</td>
#       <td>0.147397</td>
#       <td>0.942868</td>
#       <td>0.057132</td>
#       <td>08:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
full_pipe("/../training/chest-xray")
# Out:
# CONTROL
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.610491</td>
#       <td>0.174218</td>
#       <td>0.935199</td>
#       <td>0.064801</td>
#       <td>08:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.427613</td>
#       <td>0.251803</td>
#       <td>0.900307</td>
#       <td>0.099693</td>
#       <td>07:57</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.394562</td>
#       <td>0.202525</td>
#       <td>0.924847</td>
#       <td>0.075153</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.318956</td>
#       <td>0.138231</td>
#       <td>0.947086</td>
#       <td>0.052914</td>
#       <td>07:57</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %% [markdown]
# ##
